# %% [markdown]
# First, let's import the libraries necessary for this EDA. The goal is to use some visualizations and comb through this set to look for anything interesting. Also we will import the data set.

# %%
import pandas as pd
import numpy as np
import seaborn as sb #
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick
import os

nypd_df1 = pd.read_csv('NYPD_Arrest_Data__Year_to_Date_.csv')
nypd_df1.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD      PD_DESC  KY_CD   OFNS_DESC    LAW_CODE  \
# 0   220756993  11/19/2020  155.0       RAPE 2  104.0        RAPE  PL 1303001
# 1   220422940  11/12/2020  157.0       RAPE 1  104.0        RAPE  PL 1303502
# 2   218804160  10/06/2020  157.0       RAPE 1  104.0        RAPE  PL 1303501
# 3   218641095  10/02/2020  594.0  OBSCENITY 1  116.0  SEX CRIMES  PL 2631600
# 4   217890704  09/16/2020  155.0       RAPE 2  104.0        RAPE  PL 1303001
#
#   LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP  \
# 0          F           B               41                  0     18-24
# 1          F           Q              112                  0     25-44
# 2          F           M                7                  2     25-44
# 3          F           M                5                  0     25-44
# 4          F           K               77                  0     25-44
#
#   PERP_SEX       PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# ...

# %% [raw]
# Great! Let's see how many columns and rows we have.

# %%
nypd_df1.columns.values
# Out:
# array(['ARREST_KEY', 'ARREST_DATE', 'PD_CD', 'PD_DESC', 'KY_CD',
#        'OFNS_DESC', 'LAW_CODE', 'LAW_CAT_CD', 'ARREST_BORO',
#        'ARREST_PRECINCT', 'JURISDICTION_CODE', 'AGE_GROUP', 'PERP_SEX',
#        'PERP_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude', 'Longitude',
#        'New Georeferenced Column'], dtype=object)

# %%
nypd_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 140413 entries, 0 to 140412
# Data columns (total 19 columns):
# ARREST_KEY                  140413 non-null int64
# ARREST_DATE                 140413 non-null object
# PD_CD                       140390 non-null float64
# PD_DESC                     140376 non-null object
# KY_CD                       140376 non-null float64
# OFNS_DESC                   140376 non-null object
# LAW_CODE                    140413 non-null object
# LAW_CAT_CD                  139024 non-null object
# ARREST_BORO                 140413 non-null object
# ARREST_PRECINCT             140413 non-null int64
# JURISDICTION_CODE           140413 non-null int64
# AGE_GROUP                   140413 non-null object
# PERP_SEX                    140413 non-null object
# PERP_RACE                   140413 non-null object
# X_COORD_CD                  140413 non-null int64
# Y_COORD_CD                  140413 non-null int64
# ...

# %% [raw]
# Looks like we have 140413 arrests by NYPD in 2020 and most of Jan. 2021 (dataset is updated up to January 25th 2021). I want to see if there are any null values and decide if we should delete any rows or unnecessary attributes(columns).

# %%
nypd_df1.isnull().sum()
# Out:
# ARREST_KEY                     0
# ARREST_DATE                    0
# PD_CD                         23
# PD_DESC                       37
# KY_CD                         37
# OFNS_DESC                     37
# LAW_CODE                       0
# LAW_CAT_CD                  1389
# ARREST_BORO                    0
# ARREST_PRECINCT                0
# JURISDICTION_CODE              0
# AGE_GROUP                      0
# PERP_SEX                       0
# PERP_RACE                      0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# New Georeferenced Column       0
# dtype: int64

# %% [markdown]
# #Hmm looks like we have 5 columns with many null values. Here are the descriptions for those columns according to NYC OpenData (source of data set):
#
#
# *PD_CD - Three digit internal classification code (more granular than Key Code)
#
# *PD_DESC - Description of internal classification corresponding with PD code (more granular than Offense Description)
#
# *KY_CD - Three digit internal classification code (more general category than PD code)
#
# *OFNS_DESC - Description of internal classification corresponding with KY code (more general category than PD description)
#
# *LAW_CAT_CD - Level of offense: felony, misdemeanor, violation
#
#
# ##We should keep LAW_CAT_CD and OFNS_DESC since they look important for this analysis. The other 3 columns will be dropped since they seem to have more meaning to internal users. Also I will get rid of ARREST_KEY because it is likely a primary key for a table and not needed for our analysis. LAW_CODE will also be removed since it appears to be a code familiar to internal users but not needed for analysis.

# %%
columns_dropped = ['ARREST_KEY', 'PD_CD', 'KY_CD', 'LAW_CODE']
nypd_df1.drop(columns = columns_dropped, inplace = True)
nypd_df1.isnull().sum()
# Out:
# ARREST_DATE                    0
# PD_DESC                       37
# OFNS_DESC                     37
# LAW_CAT_CD                  1389
# ARREST_BORO                    0
# ARREST_PRECINCT                0
# JURISDICTION_CODE              0
# AGE_GROUP                      0
# PERP_SEX                       0
# PERP_RACE                      0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# New Georeferenced Column       0
# dtype: int64

# %% [raw]
# So we still have some nulls to address. For PD_DESC and OFNS_DESC, we can probably impute a value such as 'Unknown'. I'd rather do this than delete the rows entirely.

# %%
impute_values = {'PD_DESC': 'UNKNOWN', 'OFNS_DESC': 'UNKNOWN'}
nypd_df1.fillna(value=impute_values, inplace = True)
nypd_df1.isnull().sum()
# Out:
# ARREST_DATE                    0
# PD_DESC                        0
# OFNS_DESC                      0
# LAW_CAT_CD                  1389
# ARREST_BORO                    0
# ARREST_PRECINCT                0
# JURISDICTION_CODE              0
# AGE_GROUP                      0
# PERP_SEX                       0
# PERP_RACE                      0
# X_COORD_CD                     0
# Y_COORD_CD                     0
# Latitude                       0
# Longitude                      0
# New Georeferenced Column       0
# dtype: int64

# %%
PD_DESC_na = nypd_df1.loc[nypd_df1['PD_DESC'] == 'UNKNOWN'] #check if imputed values were inserted 
PD_DESC_na
# Out:
#        ARREST_DATE  PD_DESC OFNS_DESC LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 6       07/10/2020  UNKNOWN   UNKNOWN          M           M               17
# 374     11/11/2020  UNKNOWN   UNKNOWN          M           Q              110
# 2210    12/12/2020  UNKNOWN   UNKNOWN          F           M               23
# 2898    11/22/2020  UNKNOWN   UNKNOWN          M           K               62
# 3589    11/18/2020  UNKNOWN   UNKNOWN          M           M               26
# 7377    12/21/2020  UNKNOWN   UNKNOWN          M           K               90
# 8984    11/12/2020  UNKNOWN   UNKNOWN          M           M               13
# 9166    12/21/2020  UNKNOWN   UNKNOWN          F           Q              114
# 13506   12/03/2020  UNKNOWN   UNKNOWN          F           B               44
# 18524   11/22/2020  UNKNOWN   UNKNOWN          M           K               62
# 19607   12/03/2020  UNKNOWN   UNKNOWN          M           B               42
# ...

# %% [raw]
# Sweet! I can see PD_DESC and OFNS_DESC are completed columns with no missing values now. As for LAW_CAT_CD, we will have to do something about the 1389 missing values. The possible values for this column are 'F'(Felony), 'M'(Misdemeanor), and 'I'(violation/infraction). Let's put 'U' for the nulls in this column.

# %%
impute_LAW_CAT = {'LAW_CAT_CD': 'U'}
nypd_df1.fillna(value=impute_LAW_CAT, inplace = True)
nypd_df1.isnull().sum()
# Out:
# ARREST_DATE                 0
# PD_DESC                     0
# OFNS_DESC                   0
# LAW_CAT_CD                  0
# ARREST_BORO                 0
# ARREST_PRECINCT             0
# JURISDICTION_CODE           0
# AGE_GROUP                   0
# PERP_SEX                    0
# PERP_RACE                   0
# X_COORD_CD                  0
# Y_COORD_CD                  0
# Latitude                    0
# Longitude                   0
# New Georeferenced Column    0
# dtype: int64

# %% [raw]
# Yay no more missing values! Let's check out the cases with LAW_CAT_CD = 'U' just to make sure.

# %%
LAW_CAT_na = nypd_df1.loc[nypd_df1['LAW_CAT_CD'] == 'U'] 
LAW_CAT_na.head() # I won't print full list since I expect
# Out:
#     ARREST_DATE                 PD_DESC              OFNS_DESC LAW_CAT_CD  \
# 65   12/23/2020  U.S. CODE UNCLASSIFIED  FOR OTHER AUTHORITIES          U
# 89   12/30/2020  U.S. CODE UNCLASSIFIED  FOR OTHER AUTHORITIES          U
# 107  12/16/2020  U.S. CODE UNCLASSIFIED  FOR OTHER AUTHORITIES          U
# 121  12/08/2020  U.S. CODE UNCLASSIFIED  FOR OTHER AUTHORITIES          U
# 280  12/10/2020  U.S. CODE UNCLASSIFIED  FOR OTHER AUTHORITIES          U
#
#     ARREST_BORO  ARREST_PRECINCT  JURISDICTION_CODE AGE_GROUP PERP_SEX  \
# 65            Q              113                  0     25-44        F
# 89            B               52                  0     25-44        M
# 107           M                5                  0     45-64        F
# 121           K               84                  0     25-44        M
# 280           M                5                  0     25-44        M
#
#     PERP_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# ...

# %% [raw]
# I feel like these particular arrests were made by an authoritative body other than NYPD. I'll have to look into this another time.
# Now I want to rename some columns so they are easier to understand.

# %%
renamed_columns = {'PD_DESC': 'PD_Crime_Name', 'OFNS_DESC': 'OFFENSE', 'LAW_CAT_CD': 'Classification'}
nypd_df1.rename(columns= renamed_columns, inplace = True)
nypd_df1.columns.values
# Out:
# array(['ARREST_DATE', 'PD_Crime_Name', 'OFFENSE', 'Classification',
#        'ARREST_BORO', 'ARREST_PRECINCT', 'JURISDICTION_CODE', 'AGE_GROUP',
#        'PERP_SEX', 'PERP_RACE', 'X_COORD_CD', 'Y_COORD_CD', 'Latitude',
#        'Longitude', 'New Georeferenced Column'], dtype=object)

# %% [raw]
# Looks good to me. Now that we have a clean dataset to work with, let's check out some visualizations and statistical elements of our data. First I'll start with how many males and females commit crimes by percentage.

# %%
ax = (nypd_df1['PERP_SEX'].value_counts()*100.0 /len(nypd_df1))\
.plot.pie(autopct='%.1f%%', labels = ['M', 'F'],figsize =(7,7), fontsize = 12 )                                                                           
ax.yaxis.set_major_formatter(mtick.PercentFormatter())
ax.set_ylabel('Perpetrators',fontsize = 12)
ax.set_title('% of arrests by sex', fontsize = 12)
# Out:
# Text(0.5, 1.0, '% of arrests by sex')

# %% [raw]
# No surprises here. Men do seem to commit more crimes than women in general. Next I want the breakdown for classification (Felony, Misdemeanor, ect.). I'll use a bar chart.

# %%
ax = nypd_df1['Classification'].value_counts().plot(kind = 'bar',rot = 0, width = 0.6)
ax.set_ylabel('# of arrests')
ax.set_title('# of arrests by Classification')
# Out:
# Text(0.5, 1.0, '# of arrests by Classification')

# %% [raw]
# Makes sense to me. I expect most arrests to be misdemeanors and felonies. Now I want to see number of arrests by race.

# %%
plt.figure(figsize=(8,6))
ct = sb.countplot(x="PERP_RACE", data=nypd_df1)

ct.set_xticklabels(ct.get_xticklabels(), rotation=50, ha="right")
plt.tight_layout()
plt.show()

# %% [raw]
# Ok how about number of arrests by burrough?

# %%
plt.figure(figsize=(8,6))
ct = sb.countplot(x="ARREST_BORO", data=nypd_df1)

ct.set_xticklabels(ct.get_xticklabels(), rotation=50, ha="right")
plt.tight_layout()
plt.show()

# %% [raw]
# Here are the names of the burroughs: B(Bronx), S(Staten Island), K(Brooklyn), M(Manhattan), Q(Queens).
# Pretty even distribution except for Staten Island with the super low arrest rate.
